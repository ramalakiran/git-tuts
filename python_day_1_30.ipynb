# %% [markdown]
# <a href="https://colab.research.google.com/github/ramalakiran/git-tuts/blob/master/python_day_1_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(8+3)
# Out:
# 11

# %%
a=3
b=3.14
c='kiran'

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
d=b
type(d)
# Out:
# float

# %%
d=int(b)
type(d)
# Out:
# int

# %%
d
# Out:
# 3

# %%
e=str(d)

# %%
e
# Out:
# '3'

# %%
"""
Addong two numbers
print(8+3)
"""
print(2+3)
# Out:
# 5

# %%
a=7
b=8
c=a*b

# %%
print (type(c))
# Out:
# <class 'int'>

# %%
a=7
b=7.0
c=a*b

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
a='saif'
b=2
c=a*b

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
x=1
d=float(x)

# %%
print(type(d))
# Out:
# <class 'float'>

# %%
roll_no=10
d=str(roll_no)
print(type(d))
# Out:
# <class 'str'>

# %%
print('kiran')
print('ramala')
# Out:
# kiran
# ramala

# %%
print('kiran', end=' ')
print('ramala')
# Out:
# kiran ramala

# %%
print('kiran', end=' ')
print('ramala')
print('Digital Marketer')
# Out:
# kiran ramala
# Digital Marketer

# %%
print(a,b)
# Out:
# saif 2

# %%
a=2
b=3.14

# %%
print(a,b)
# Out:
# 3 2

# %%
print(a,b, sep='-')
# Out:
# 2-3.14

# %%
print(a,b,sep='\n')
# Out:
# 2
# 3.14

# %%
a=input()
# Out:
# 5

# %%
# Out:
# 5

# %%
num1=input('please enter the first number')
num2=input('please enter the first number')
# Out:
# please enter the first number3
# please enter the first number6

# %%
print(num1,num2, sep='\n')
# Out:
# 3
# 6

# %%
res=num1 + num2

# %%
print(res)
# Out:
# 36

# %%
num1 = int(num1)
num2 = int(num2)
res = num1 + num2
print(res)
# Out:
# 9

# %%
5<<2
# Out:
# 20

# %%
5>>2
# Out:
# 1

# %%
a = 2
a *= 2
b = a // 2
print(a,b)
# Out:
# 4 2

# %%
#swap two numbers

a=int(input("Enter first number a= "))
b=int(input("Enter first number b= "))

print("Before swapping: a =", a, "b =", b)

temp = a
a = b
b = temp

print("After swapping: a =", a, "b =", b)
# Out:
# Enter first number a= 10
# Enter first number b= 15
# Before swapping: a = 10 b = 15
# After swapping: a = 15 b = 10
